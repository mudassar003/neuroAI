# %%
# Cell 1: Import required libraries
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import csv
from datetime import datetime
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.regularizers import l2

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.15.0

# %%
# Cell 2: Initialize TPU and set up strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU:', tpu.master())
except ValueError:
    tpu = None
    print('Not connected to a TPU runtime')

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
print("REPLICAS:", strategy.num_replicas_in_sync)

from google.colab import drive
drive.mount('/content/drive')

# Create a local directory to store your dataset in Colab
# !mkdir /content/local_data

# Path to your data in Google Drive
google_drive_data_path = '/content/drive/My Drive/ML_Data/final_dataset_split.zip'  # Note the trailing slash

# Local path where you want to store the copied data
local_data_path = '/content/local_data/'  # Copy into a "resized" folder inside local_data

# Use rsync for faster copying of data
# !rsync -avh --progress "$google_drive_data_path" "$local_data_path"


# Define the path to the zip file
zip_file_path = '/content/local_data/final_dataset_split.zip'

# Define the extraction path
extracted_data_path = '/content/local_data'

# Unzip the file
# !unzip -q {zip_file_path} -d {extracted_data_path}

# List the files to verify
# !ls {extracted_data_path}
# Out:
# Running on TPU:
# REPLICAS: 8
# Mounted at /content/drive
# sending incremental file list
# final_dataset_split.zip
#         758.43M 100%   96.60MB/s    0:00:07 (xfr#1, to-chk=0/1)
#
# sent 758.62M bytes  received 35 bytes  89.25M bytes/sec
# total size is 758.43M  speedup is 1.00
# final_dataset_split  final_dataset_split.zip

# %%
# Cell 3: Define dataset paths and data loaders

MODEL_SAVE_PATH = "/content/drive/My Drive/ML_Data/saved_model/triangle/"
DATASET_BASE_PATH = '/content/local_data/final_dataset_split'
# DATASET_BASE_PATH = 'gs://mudassar_dataset/final_dataset_split'

print(f"Model save path: {MODEL_SAVE_PATH}")
print(f"Dataset base path: {DATASET_BASE_PATH}")
# Out:
# Model save path: /content/drive/My Drive/ML_Data/saved_model/triangle/
# Dataset base path: /content/local_data/final_dataset_split

# %%
# Cell 4: Load data using tf.data.Dataset
def load_data():
    BATCH_SIZE = 128 * strategy.num_replicas_in_sync  # Adjust as needed
    IMG_SIZE = (224, 224)
    # NUM_CHANNELS = 1

    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
        os.path.join(DATASET_BASE_PATH, 'train'),
        labels='inferred',
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        # color_mode='grayscale',
        shuffle=True
    )

    validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
        os.path.join(DATASET_BASE_PATH, 'val'),
        labels='inferred',
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        # color_mode='grayscale',
        shuffle=False
    )

    test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
        os.path.join(DATASET_BASE_PATH, 'test'),
        labels='inferred',
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        # color_mode='grayscale',
        shuffle=False
    )

    return train_dataset, validation_dataset, test_dataset

# %%
# Cell 5: Load data and output number of images in each set
train_dataset, validation_dataset, test_dataset = load_data()

# Get class names and number of classes
class_names = train_dataset.class_names
num_classes = len(class_names)
print(f"Class names: {class_names}")
print(f"Number of classes: {num_classes}")

# Output number of images in each dataset
train_image_count = sum([len(files) for r, d, files in os.walk(os.path.join(DATASET_BASE_PATH, 'train'))])
val_image_count = sum([len(files) for r, d, files in os.walk(os.path.join(DATASET_BASE_PATH, 'val'))])
test_image_count = sum([len(files) for r, d, files in os.walk(os.path.join(DATASET_BASE_PATH, 'test'))])

print(f"Number of training images: {train_image_count}")
print(f"Number of validation images: {val_image_count}")
print(f"Number of test images: {test_image_count}")
# Out:
# Found 40270 files belonging to 3 classes.
# Found 8628 files belonging to 3 classes.
# Found 8632 files belonging to 3 classes.
# Class names: ['hc', 'pd', 'prodromal']
# Number of classes: 3
# Number of training images: 40270
# Number of validation images: 8629
# Number of test images: 8632

# %%
# Cell 6: Data verification - Display 9 images
def display_sample_images(dataset, class_names):
    plt.figure(figsize=(15, 10))
    for images, labels in dataset.take(1):
        class_counts = {i: 0 for i in range(num_classes)}
        images_displayed = 0
        for idx in range(len(images)):
            class_idx = tf.argmax(labels[idx]).numpy()
            if class_counts[class_idx] < 3:
                plt.subplot(3, 3, images_displayed + 1)
                plt.imshow(images[idx].numpy().astype("uint8"))
                plt.title(f"Label: {class_names[class_idx]}")
                plt.axis('off')
                class_counts[class_idx] += 1
                images_displayed += 1
            if images_displayed == 9:
                break
    plt.suptitle('Sample Training Images (3 per Class)')
    plt.tight_layout()
    plt.show()

display_sample_images(train_dataset, class_names)

# %%
# Cell 7: Build the MobileNetV3 Classification Model with Triangular Layer Structure

def mobilenetv3_classification_model(input_shape, num_classes):
    regularization = l2(0.0001)

    base_model = MobileNetV3Large(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = False  # Freeze the base model

    # Add custom layers for classification
    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)

    # First half of the triangular pattern (Increasing the size)
    x = Dense(256, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.2)(x)  # Shallow layer dropout

    x = Dense(512, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.25)(x)

    x = Dense(1024, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.3)(x)

    x = Dense(2048, activation='relu', kernel_regularizer=regularization)(x)  # Peak of the triangle
    x = Dropout(0.4)(x)

    # Second half of the triangular pattern (Decreasing the size)
    x = Dense(2048, activation='relu', kernel_regularizer=regularization)(x)  # Still at the peak
    x = Dropout(0.4)(x)

    x = Dense(1024, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.3)(x)

    x = Dense(512, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.25)(x)

    x = Dense(256, activation='relu', kernel_regularizer=regularization)(x)
    x = Dropout(0.2)(x)

    # Output layer for classification
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)

with strategy.scope():
    model = mobilenetv3_classification_model(input_shape, num_classes)

    # Compile the model with Adam optimizer
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=[
            'accuracy',                   # Track accuracy
            tf.keras.metrics.Precision(),  # Precision metric
            tf.keras.metrics.Recall(),     # Recall metric
            tf.keras.metrics.AUC(name='auc')  # AUC metric for overall performance
        ]
    )

    # Display the model summary
    model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  MobilenetV3large (Function  (None, 7, 7, 960)         2996352
#  al)
#
#  global_average_pooling2d_1  (None, 960)               0
#   (GlobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 256)               246016
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 512)               131584
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 1024)              525312
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_12 (Dense)            (None, 2048)              2099200
#
#  dropout_11 (Dropout)        (None, 2048)              0
#
#  dense_13 (Dense)            (None, 2048)              4196352
#
#  dropout_12 (Dropout)        (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1024)              2098176
#
#  dropout_13 (Dropout)        (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 12949891 (49.40 MB)
# Trainable params: 9953539 (37.97 MB)
# Non-trainable params: 2996352 (11.43 MB)
# _________________________________________________________________

# %%
# Cell 8: Training of model

EPOCHS = 100  # Define the number of epochs

# Wrap training and saving within the TPU strategy scope
with strategy.scope():
    # Train the model with the LR callback
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=EPOCHS,
        verbose=2  # Display progress with a progress bar
    )

    # Save the model with a timestamp
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    model_save_path_with_timestamp = os.path.join(MODEL_SAVE_PATH, f"mobilenetv3_model_{timestamp}.h5")

    # Save the model without wrapping in tf.device
    model.save(model_save_path_with_timestamp)
    print(f"Model saved to: {model_save_path_with_timestamp}")
# Out:
# Epoch 1/100
# 40/40 - 73s - loss: 1.8218 - accuracy: 0.3448 - precision_1: 0.3502 - recall_1: 0.0024 - auc: 0.5112 - val_loss: 1.7989 - val_accuracy: 0.4001 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc: 0.5894 - 73s/epoch - 2s/step
# Epoch 2/100
# 40/40 - 28s - loss: 1.7905 - accuracy: 0.3767 - precision_1: 0.4097 - recall_1: 0.0015 - auc: 0.5578 - val_loss: 1.7614 - val_accuracy: 0.4133 - val_precision_1: 1.0000 - val_recall_1: 4.6361e-04 - val_auc: 0.6079 - 28s/epoch - 693ms/step
# Epoch 3/100
# 40/40 - 27s - loss: 1.7501 - accuracy: 0.4218 - precision_1: 0.5391 - recall_1: 0.0454 - auc: 0.6102 - val_loss: 1.6976 - val_accuracy: 0.4845 - val_precision_1: 0.6518 - val_recall_1: 0.0560 - val_auc: 0.6725 - 27s/epoch - 687ms/step
# Epoch 4/100
# 40/40 - 28s - loss: 1.6851 - accuracy: 0.4816 - precision_1: 0.5702 - recall_1: 0.1794 - auc: 0.6726 - val_loss: 1.6138 - val_accuracy: 0.5348 - val_precision_1: 0.6425 - val_recall_1: 0.2581 - val_auc: 0.7322 - 28s/epoch - 697ms/step
# Epoch 5/100
# 40/40 - 27s - loss: 1.6134 - accuracy: 0.5288 - precision_1: 0.5990 - recall_1: 0.3203 - auc: 0.7222 - val_loss: 1.5479 - val_accuracy: 0.5721 - val_precision_1: 0.6514 - val_recall_1: 0.3599 - val_auc: 0.7666 - 27s/epoch - 687ms/step
# Epoch 6/100
# 40/40 - 28s - loss: 1.5571 - accuracy: 0.5625 - precision_1: 0.6229 - recall_1: 0.3998 - auc: 0.7532 - val_loss: 1.4885 - val_accuracy: 0.6023 - val_precision_1: 0.6766 - val_recall_1: 0.4408 - val_auc: 0.7940 - 28s/epoch - 701ms/step
# Epoch 7/100
# 40/40 - 28s - loss: 1.5042 - accuracy: 0.5860 - precision_1: 0.6386 - recall_1: 0.4578 - auc: 0.7779 - val_loss: 1.4494 - val_accuracy: 0.6172 - val_precision_1: 0.6778 - val_recall_1: 0.4818 - val_auc: 0.8074 - 28s/epoch - 708ms/step
# Epoch 8/100
# 40/40 - 28s - loss: 1.4606 - accuracy: 0.6039 - precision_1: 0.6540 - recall_1: 0.4929 - auc: 0.7951 - val_loss: 1.4019 - val_accuracy: 0.6365 - val_precision_1: 0.6906 - val_recall_1: 0.5308 - val_auc: 0.8246 - 28s/epoch - 706ms/step
# Epoch 9/100
# 40/40 - 28s - loss: 1.4181 - accuracy: 0.6243 - precision_1: 0.6687 - recall_1: 0.5304 - auc: 0.8114 - val_loss: 1.3642 - val_accuracy: 0.6535 - val_precision_1: 0.7079 - val_recall_1: 0.5526 - val_auc: 0.8369 - 28s/epoch - 699ms/step
# Epoch 10/100
# 40/40 - 27s - loss: 1.3727 - accuracy: 0.6419 - precision_1: 0.6835 - recall_1: 0.5618 - auc: 0.8279 - val_loss: 1.3204 - val_accuracy: 0.6736 - val_precision_1: 0.7281 - val_recall_1: 0.5783 - val_auc: 0.8528 - 27s/epoch - 686ms/step
# Epoch 11/100
# 40/40 - 28s - loss: 1.3350 - accuracy: 0.6549 - precision_1: 0.6959 - recall_1: 0.5823 - auc: 0.8398 - val_loss: 1.2892 - val_accuracy: 0.6818 - val_precision_1: 0.7290 - val_recall_1: 0.6057 - val_auc: 0.8592 - 28s/epoch - 691ms/step
# Epoch 12/100
# 40/40 - 29s - loss: 1.2946 - accuracy: 0.6712 - precision_1: 0.7079 - recall_1: 0.6067 - auc: 0.8526 - val_loss: 1.2433 - val_accuracy: 0.6917 - val_precision_1: 0.7309 - val_recall_1: 0.6344 - val_auc: 0.8717 - 29s/epoch - 714ms/step
# Epoch 13/100
# 40/40 - 28s - loss: 1.2615 - accuracy: 0.6859 - precision_1: 0.7212 - recall_1: 0.6248 - auc: 0.8621 - val_loss: 1.2158 - val_accuracy: 0.7071 - val_precision_1: 0.7468 - val_recall_1: 0.6442 - val_auc: 0.8789 - 28s/epoch - 708ms/step
# Epoch 14/100
# 40/40 - 28s - loss: 1.2268 - accuracy: 0.6970 - precision_1: 0.7301 - recall_1: 0.6410 - auc: 0.8713 - val_loss: 1.1817 - val_accuracy: 0.7209 - val_precision_1: 0.7612 - val_recall_1: 0.6573 - val_auc: 0.8885 - 28s/epoch - 699ms/step
# Epoch 15/100
# 40/40 - 29s - loss: 1.1907 - accuracy: 0.7098 - precision_1: 0.7409 - recall_1: 0.6593 - auc: 0.8810 - val_loss: 1.1506 - val_accuracy: 0.7267 - val_precision_1: 0.7625 - val_recall_1: 0.6717 - val_auc: 0.8952 - 29s/epoch - 715ms/step
# Epoch 16/100
# 40/40 - 28s - loss: 1.1624 - accuracy: 0.7204 - precision_1: 0.7511 - recall_1: 0.6724 - auc: 0.8876 - val_loss: 1.1177 - val_accuracy: 0.7370 - val_precision_1: 0.7724 - val_recall_1: 0.6832 - val_auc: 0.9028 - 28s/epoch - 711ms/step
# Epoch 17/100
# 40/40 - 29s - loss: 1.1259 - accuracy: 0.7314 - precision_1: 0.7596 - recall_1: 0.6899 - auc: 0.8967 - val_loss: 1.0940 - val_accuracy: 0.7448 - val_precision_1: 0.7845 - val_recall_1: 0.6871 - val_auc: 0.9083 - 29s/epoch - 728ms/step
# Epoch 18/100
# 40/40 - 28s - loss: 1.0934 - accuracy: 0.7432 - precision_1: 0.7713 - recall_1: 0.7010 - auc: 0.9044 - val_loss: 1.0631 - val_accuracy: 0.7539 - val_precision_1: 0.7907 - val_recall_1: 0.7057 - val_auc: 0.9137 - 28s/epoch - 710ms/step
# Epoch 19/100
# 40/40 - 28s - loss: 1.0659 - accuracy: 0.7498 - precision_1: 0.7766 - recall_1: 0.7126 - auc: 0.9100 - val_loss: 1.0388 - val_accuracy: 0.7595 - val_precision_1: 0.7912 - val_recall_1: 0.7159 - val_auc: 0.9181 - 28s/epoch - 711ms/step
# Epoch 20/100
# 40/40 - 29s - loss: 1.0402 - accuracy: 0.7574 - precision_1: 0.7830 - recall_1: 0.7226 - auc: 0.9152 - val_loss: 1.0153 - val_accuracy: 0.7712 - val_precision_1: 0.8012 - val_recall_1: 0.7246 - val_auc: 0.9227 - 29s/epoch - 730ms/step
# Epoch 21/100
# 40/40 - 28s - loss: 1.0116 - accuracy: 0.7690 - precision_1: 0.7923 - recall_1: 0.7367 - auc: 0.9211 - val_loss: 0.9990 - val_accuracy: 0.7698 - val_precision_1: 0.8021 - val_recall_1: 0.7331 - val_auc: 0.9238 - 28s/epoch - 711ms/step
# Epoch 22/100
# 40/40 - 28s - loss: 0.9867 - accuracy: 0.7765 - precision_1: 0.7982 - recall_1: 0.7460 - auc: 0.9257 - val_loss: 0.9670 - val_accuracy: 0.7834 - val_precision_1: 0.8079 - val_recall_1: 0.7472 - val_auc: 0.9304 - 28s/epoch - 709ms/step
# Epoch 23/100
# 40/40 - 29s - loss: 0.9624 - accuracy: 0.7838 - precision_1: 0.8032 - recall_1: 0.7559 - auc: 0.9298 - val_loss: 0.9510 - val_accuracy: 0.7858 - val_precision_1: 0.8134 - val_recall_1: 0.7507 - val_auc: 0.9324 - 29s/epoch - 728ms/step
# Epoch 24/100
# 40/40 - 29s - loss: 0.9414 - accuracy: 0.7912 - precision_1: 0.8126 - recall_1: 0.7648 - auc: 0.9336 - val_loss: 0.9310 - val_accuracy: 0.7932 - val_precision_1: 0.8180 - val_recall_1: 0.7593 - val_auc: 0.9355 - 29s/epoch - 737ms/step
# Epoch 25/100
# 40/40 - 28s - loss: 0.9161 - accuracy: 0.7978 - precision_1: 0.8177 - recall_1: 0.7749 - auc: 0.9378 - val_loss: 0.9085 - val_accuracy: 0.7972 - val_precision_1: 0.8234 - val_recall_1: 0.7641 - val_auc: 0.9393 - 28s/epoch - 711ms/step
# Epoch 26/100
# 40/40 - 29s - loss: 0.8909 - accuracy: 0.8046 - precision_1: 0.8240 - recall_1: 0.7831 - auc: 0.9422 - val_loss: 0.8944 - val_accuracy: 0.7989 - val_precision_1: 0.8218 - val_recall_1: 0.7696 - val_auc: 0.9407 - 29s/epoch - 727ms/step
# Epoch 27/100
# 40/40 - 30s - loss: 0.8740 - accuracy: 0.8108 - precision_1: 0.8277 - recall_1: 0.7898 - auc: 0.9445 - val_loss: 0.8757 - val_accuracy: 0.8084 - val_precision_1: 0.8316 - val_recall_1: 0.7791 - val_auc: 0.9434 - 30s/epoch - 761ms/step
# Epoch 28/100
# 40/40 - 29s - loss: 0.8565 - accuracy: 0.8130 - precision_1: 0.8312 - recall_1: 0.7929 - auc: 0.9467 - val_loss: 0.8608 - val_accuracy: 0.8078 - val_precision_1: 0.8314 - val_recall_1: 0.7813 - val_auc: 0.9450 - 29s/epoch - 715ms/step
# Epoch 29/100
# 40/40 - 29s - loss: 0.8313 - accuracy: 0.8242 - precision_1: 0.8387 - recall_1: 0.8051 - auc: 0.9510 - val_loss: 0.8411 - val_accuracy: 0.8158 - val_precision_1: 0.8357 - val_recall_1: 0.7918 - val_auc: 0.9480 - 29s/epoch - 715ms/step
# Epoch 30/100
# 40/40 - 28s - loss: 0.8161 - accuracy: 0.8259 - precision_1: 0.8412 - recall_1: 0.8085 - auc: 0.9526 - val_loss: 0.8271 - val_accuracy: 0.8180 - val_precision_1: 0.8392 - val_recall_1: 0.7938 - val_auc: 0.9496 - 28s/epoch - 702ms/step
# Epoch 31/100
# 40/40 - 29s - loss: 0.7996 - accuracy: 0.8297 - precision_1: 0.8441 - recall_1: 0.8130 - auc: 0.9547 - val_loss: 0.8140 - val_accuracy: 0.8248 - val_precision_1: 0.8427 - val_recall_1: 0.7995 - val_auc: 0.9511 - 29s/epoch - 713ms/step
# Epoch 32/100
# 40/40 - 29s - loss: 0.7776 - accuracy: 0.8364 - precision_1: 0.8500 - recall_1: 0.8208 - auc: 0.9580 - val_loss: 0.7964 - val_accuracy: 0.8279 - val_precision_1: 0.8446 - val_recall_1: 0.8054 - val_auc: 0.9535 - 29s/epoch - 720ms/step
# Epoch 33/100
# 40/40 - 29s - loss: 0.7605 - accuracy: 0.8423 - precision_1: 0.8563 - recall_1: 0.8267 - auc: 0.9601 - val_loss: 0.7808 - val_accuracy: 0.8289 - val_precision_1: 0.8474 - val_recall_1: 0.8091 - val_auc: 0.9554 - 29s/epoch - 716ms/step
# Epoch 34/100
# 40/40 - 29s - loss: 0.7478 - accuracy: 0.8433 - precision_1: 0.8548 - recall_1: 0.8292 - auc: 0.9613 - val_loss: 0.7690 - val_accuracy: 0.8340 - val_precision_1: 0.8484 - val_recall_1: 0.8161 - val_auc: 0.9563 - 29s/epoch - 733ms/step
# Epoch 35/100
# 40/40 - 29s - loss: 0.7361 - accuracy: 0.8468 - precision_1: 0.8595 - recall_1: 0.8338 - auc: 0.9624 - val_loss: 0.7612 - val_accuracy: 0.8339 - val_precision_1: 0.8511 - val_recall_1: 0.8134 - val_auc: 0.9567 - 29s/epoch - 730ms/step
# Epoch 36/100
# 40/40 - 30s - loss: 0.7192 - accuracy: 0.8512 - precision_1: 0.8635 - recall_1: 0.8380 - auc: 0.9645 - val_loss: 0.7575 - val_accuracy: 0.8343 - val_precision_1: 0.8483 - val_recall_1: 0.8194 - val_auc: 0.9562 - 30s/epoch - 755ms/step
# Epoch 37/100
# 40/40 - 29s - loss: 0.7008 - accuracy: 0.8576 - precision_1: 0.8680 - recall_1: 0.8450 - auc: 0.9667 - val_loss: 0.7364 - val_accuracy: 0.8411 - val_precision_1: 0.8536 - val_recall_1: 0.8268 - val_auc: 0.9593 - 29s/epoch - 714ms/step
# Epoch 38/100
# 40/40 - 28s - loss: 0.6875 - accuracy: 0.8603 - precision_1: 0.8710 - recall_1: 0.8481 - auc: 0.9681 - val_loss: 0.7183 - val_accuracy: 0.8490 - val_precision_1: 0.8608 - val_recall_1: 0.8316 - val_auc: 0.9619 - 28s/epoch - 712ms/step
# Epoch 39/100
# 40/40 - 30s - loss: 0.6676 - accuracy: 0.8682 - precision_1: 0.8776 - recall_1: 0.8578 - auc: 0.9707 - val_loss: 0.7143 - val_accuracy: 0.8463 - val_precision_1: 0.8594 - val_recall_1: 0.8328 - val_auc: 0.9617 - 30s/epoch - 755ms/step
# Epoch 40/100
# 40/40 - 29s - loss: 0.6605 - accuracy: 0.8678 - precision_1: 0.8757 - recall_1: 0.8584 - auc: 0.9707 - val_loss: 0.6977 - val_accuracy: 0.8528 - val_precision_1: 0.8637 - val_recall_1: 0.8388 - val_auc: 0.9636 - 29s/epoch - 717ms/step
# Epoch 41/100
# 40/40 - 29s - loss: 0.6407 - accuracy: 0.8741 - precision_1: 0.8824 - recall_1: 0.8645 - auc: 0.9734 - val_loss: 0.6944 - val_accuracy: 0.8532 - val_precision_1: 0.8631 - val_recall_1: 0.8423 - val_auc: 0.9634 - 29s/epoch - 714ms/step
# Epoch 42/100
# 40/40 - 29s - loss: 0.6364 - accuracy: 0.8725 - precision_1: 0.8816 - recall_1: 0.8642 - auc: 0.9730 - val_loss: 0.6841 - val_accuracy: 0.8527 - val_precision_1: 0.8623 - val_recall_1: 0.8421 - val_auc: 0.9643 - 29s/epoch - 736ms/step
# Epoch 43/100
# 40/40 - 30s - loss: 0.6244 - accuracy: 0.8758 - precision_1: 0.8834 - recall_1: 0.8674 - auc: 0.9741 - val_loss: 0.6753 - val_accuracy: 0.8563 - val_precision_1: 0.8677 - val_recall_1: 0.8462 - val_auc: 0.9649 - 30s/epoch - 754ms/step
# Epoch 44/100
# 40/40 - 29s - loss: 0.6147 - accuracy: 0.8776 - precision_1: 0.8860 - recall_1: 0.8689 - auc: 0.9750 - val_loss: 0.6650 - val_accuracy: 0.8577 - val_precision_1: 0.8672 - val_recall_1: 0.8467 - val_auc: 0.9660 - 29s/epoch - 726ms/step
# Epoch 45/100
# 40/40 - 29s - loss: 0.6027 - accuracy: 0.8826 - precision_1: 0.8907 - recall_1: 0.8749 - auc: 0.9760 - val_loss: 0.6602 - val_accuracy: 0.8579 - val_precision_1: 0.8679 - val_recall_1: 0.8500 - val_auc: 0.9661 - 29s/epoch - 729ms/step
# Epoch 46/100
# 40/40 - 30s - loss: 0.5889 - accuracy: 0.8871 - precision_1: 0.8933 - recall_1: 0.8802 - auc: 0.9774 - val_loss: 0.6477 - val_accuracy: 0.8638 - val_precision_1: 0.8707 - val_recall_1: 0.8537 - val_auc: 0.9675 - 30s/epoch - 762ms/step
# Epoch 47/100
# 40/40 - 29s - loss: 0.5825 - accuracy: 0.8863 - precision_1: 0.8933 - recall_1: 0.8788 - auc: 0.9776 - val_loss: 0.6427 - val_accuracy: 0.8609 - val_precision_1: 0.8693 - val_recall_1: 0.8520 - val_auc: 0.9675 - 29s/epoch - 723ms/step
# Epoch 48/100
# 40/40 - 29s - loss: 0.5642 - accuracy: 0.8936 - precision_1: 0.8994 - recall_1: 0.8869 - auc: 0.9798 - val_loss: 0.6337 - val_accuracy: 0.8658 - val_precision_1: 0.8732 - val_recall_1: 0.8570 - val_auc: 0.9687 - 29s/epoch - 729ms/step
# Epoch 49/100
# 40/40 - 28s - loss: 0.5591 - accuracy: 0.8926 - precision_1: 0.8987 - recall_1: 0.8861 - auc: 0.9798 - val_loss: 0.6251 - val_accuracy: 0.8664 - val_precision_1: 0.8722 - val_recall_1: 0.8581 - val_auc: 0.9691 - 28s/epoch - 707ms/step
# Epoch 50/100
# 40/40 - 29s - loss: 0.5437 - accuracy: 0.8962 - precision_1: 0.9019 - recall_1: 0.8898 - auc: 0.9813 - val_loss: 0.6244 - val_accuracy: 0.8695 - val_precision_1: 0.8752 - val_recall_1: 0.8640 - val_auc: 0.9690 - 29s/epoch - 719ms/step
# Epoch 51/100
# 40/40 - 29s - loss: 0.5362 - accuracy: 0.8990 - precision_1: 0.9042 - recall_1: 0.8932 - auc: 0.9818 - val_loss: 0.6096 - val_accuracy: 0.8705 - val_precision_1: 0.8773 - val_recall_1: 0.8640 - val_auc: 0.9705 - 29s/epoch - 729ms/step
# Epoch 52/100
# 40/40 - 29s - loss: 0.5279 - accuracy: 0.9010 - precision_1: 0.9061 - recall_1: 0.8958 - auc: 0.9824 - val_loss: 0.5983 - val_accuracy: 0.8738 - val_precision_1: 0.8813 - val_recall_1: 0.8657 - val_auc: 0.9714 - 29s/epoch - 718ms/step
# Epoch 53/100
# 40/40 - 29s - loss: 0.5178 - accuracy: 0.9034 - precision_1: 0.9088 - recall_1: 0.8983 - auc: 0.9831 - val_loss: 0.5958 - val_accuracy: 0.8727 - val_precision_1: 0.8775 - val_recall_1: 0.8676 - val_auc: 0.9714 - 29s/epoch - 727ms/step
# Epoch 54/100
# 40/40 - 29s - loss: 0.5076 - accuracy: 0.9056 - precision_1: 0.9101 - recall_1: 0.9002 - auc: 0.9840 - val_loss: 0.5876 - val_accuracy: 0.8782 - val_precision_1: 0.8850 - val_recall_1: 0.8724 - val_auc: 0.9720 - 29s/epoch - 722ms/step
# Epoch 55/100
# 40/40 - 31s - loss: 0.4995 - accuracy: 0.9088 - precision_1: 0.9127 - recall_1: 0.9043 - auc: 0.9844 - val_loss: 0.5812 - val_accuracy: 0.8763 - val_precision_1: 0.8820 - val_recall_1: 0.8707 - val_auc: 0.9726 - 31s/epoch - 777ms/step
# Epoch 56/100
# 40/40 - 29s - loss: 0.4934 - accuracy: 0.9088 - precision_1: 0.9137 - recall_1: 0.9049 - auc: 0.9848 - val_loss: 0.5769 - val_accuracy: 0.8760 - val_precision_1: 0.8824 - val_recall_1: 0.8702 - val_auc: 0.9725 - 29s/epoch - 716ms/step
# Epoch 57/100
# 40/40 - 28s - loss: 0.4875 - accuracy: 0.9087 - precision_1: 0.9137 - recall_1: 0.9042 - auc: 0.9850 - val_loss: 0.5706 - val_accuracy: 0.8798 - val_precision_1: 0.8847 - val_recall_1: 0.8748 - val_auc: 0.9731 - 28s/epoch - 711ms/step
# Epoch 58/100
# 40/40 - 31s - loss: 0.4734 - accuracy: 0.9138 - precision_1: 0.9176 - recall_1: 0.9100 - auc: 0.9862 - val_loss: 0.5642 - val_accuracy: 0.8804 - val_precision_1: 0.8842 - val_recall_1: 0.8746 - val_auc: 0.9736 - 31s/epoch - 764ms/step
# Epoch 59/100
# 40/40 - 29s - loss: 0.4669 - accuracy: 0.9147 - precision_1: 0.9193 - recall_1: 0.9109 - auc: 0.9867 - val_loss: 0.5598 - val_accuracy: 0.8805 - val_precision_1: 0.8856 - val_recall_1: 0.8751 - val_auc: 0.9739 - 29s/epoch - 717ms/step
# Epoch 60/100
# 40/40 - 29s - loss: 0.4579 - accuracy: 0.9180 - precision_1: 0.9217 - recall_1: 0.9144 - auc: 0.9873 - val_loss: 0.5547 - val_accuracy: 0.8825 - val_precision_1: 0.8866 - val_recall_1: 0.8774 - val_auc: 0.9743 - 29s/epoch - 724ms/step
# Epoch 61/100
# 40/40 - 29s - loss: 0.4533 - accuracy: 0.9174 - precision_1: 0.9213 - recall_1: 0.9138 - auc: 0.9874 - val_loss: 0.5443 - val_accuracy: 0.8847 - val_precision_1: 0.8891 - val_recall_1: 0.8809 - val_auc: 0.9751 - 29s/epoch - 730ms/step
# Epoch 62/100
# 40/40 - 31s - loss: 0.4439 - accuracy: 0.9203 - precision_1: 0.9235 - recall_1: 0.9170 - auc: 0.9880 - val_loss: 0.5506 - val_accuracy: 0.8814 - val_precision_1: 0.8850 - val_recall_1: 0.8771 - val_auc: 0.9742 - 31s/epoch - 763ms/step
# Epoch 63/100
# 40/40 - 30s - loss: 0.4408 - accuracy: 0.9208 - precision_1: 0.9243 - recall_1: 0.9178 - auc: 0.9880 - val_loss: 0.5381 - val_accuracy: 0.8861 - val_precision_1: 0.8910 - val_recall_1: 0.8814 - val_auc: 0.9756 - 30s/epoch - 743ms/step
# Epoch 64/100
# 40/40 - 29s - loss: 0.4360 - accuracy: 0.9203 - precision_1: 0.9234 - recall_1: 0.9169 - auc: 0.9883 - val_loss: 0.5283 - val_accuracy: 0.8856 - val_precision_1: 0.8890 - val_recall_1: 0.8809 - val_auc: 0.9761 - 29s/epoch - 736ms/step
# Epoch 65/100
# 40/40 - 30s - loss: 0.4214 - accuracy: 0.9255 - precision_1: 0.9292 - recall_1: 0.9226 - auc: 0.9896 - val_loss: 0.5347 - val_accuracy: 0.8836 - val_precision_1: 0.8877 - val_recall_1: 0.8802 - val_auc: 0.9752 - 30s/epoch - 759ms/step
# Epoch 66/100
# 40/40 - 29s - loss: 0.4199 - accuracy: 0.9266 - precision_1: 0.9300 - recall_1: 0.9234 - auc: 0.9892 - val_loss: 0.5246 - val_accuracy: 0.8873 - val_precision_1: 0.8922 - val_recall_1: 0.8825 - val_auc: 0.9760 - 29s/epoch - 728ms/step
# Epoch 67/100
# 40/40 - 30s - loss: 0.4155 - accuracy: 0.9261 - precision_1: 0.9293 - recall_1: 0.9233 - auc: 0.9895 - val_loss: 0.5197 - val_accuracy: 0.8906 - val_precision_1: 0.8938 - val_recall_1: 0.8866 - val_auc: 0.9765 - 30s/epoch - 741ms/step
# Epoch 68/100
# 40/40 - 29s - loss: 0.4074 - accuracy: 0.9286 - precision_1: 0.9315 - recall_1: 0.9259 - auc: 0.9900 - val_loss: 0.5161 - val_accuracy: 0.8890 - val_precision_1: 0.8917 - val_recall_1: 0.8854 - val_auc: 0.9767 - 29s/epoch - 726ms/step
# Epoch 69/100
# 40/40 - 29s - loss: 0.4001 - accuracy: 0.9298 - precision_1: 0.9329 - recall_1: 0.9271 - auc: 0.9905 - val_loss: 0.5131 - val_accuracy: 0.8922 - val_precision_1: 0.8951 - val_recall_1: 0.8889 - val_auc: 0.9769 - 29s/epoch - 720ms/step
# Epoch 70/100
# 40/40 - 29s - loss: 0.4005 - accuracy: 0.9308 - precision_1: 0.9335 - recall_1: 0.9284 - auc: 0.9901 - val_loss: 0.5147 - val_accuracy: 0.8883 - val_precision_1: 0.8923 - val_recall_1: 0.8855 - val_auc: 0.9762 - 29s/epoch - 732ms/step
# Epoch 71/100
# 40/40 - 29s - loss: 0.3921 - accuracy: 0.9320 - precision_1: 0.9344 - recall_1: 0.9295 - auc: 0.9907 - val_loss: 0.5051 - val_accuracy: 0.8946 - val_precision_1: 0.8972 - val_recall_1: 0.8908 - val_auc: 0.9775 - 29s/epoch - 718ms/step
# Epoch 72/100
# 40/40 - 29s - loss: 0.3860 - accuracy: 0.9319 - precision_1: 0.9346 - recall_1: 0.9300 - auc: 0.9912 - val_loss: 0.5071 - val_accuracy: 0.8893 - val_precision_1: 0.8923 - val_recall_1: 0.8866 - val_auc: 0.9767 - 29s/epoch - 735ms/step
# Epoch 73/100
# 40/40 - 29s - loss: 0.3809 - accuracy: 0.9339 - precision_1: 0.9364 - recall_1: 0.9319 - auc: 0.9913 - val_loss: 0.4999 - val_accuracy: 0.8920 - val_precision_1: 0.8944 - val_recall_1: 0.8889 - val_auc: 0.9773 - 29s/epoch - 722ms/step
# Epoch 74/100
# 40/40 - 31s - loss: 0.3780 - accuracy: 0.9347 - precision_1: 0.9372 - recall_1: 0.9323 - auc: 0.9914 - val_loss: 0.4971 - val_accuracy: 0.8911 - val_precision_1: 0.8941 - val_recall_1: 0.8873 - val_auc: 0.9770 - 31s/epoch - 771ms/step
# Epoch 75/100
# 40/40 - 29s - loss: 0.3710 - accuracy: 0.9358 - precision_1: 0.9379 - recall_1: 0.9338 - auc: 0.9919 - val_loss: 0.4940 - val_accuracy: 0.8926 - val_precision_1: 0.8956 - val_recall_1: 0.8899 - val_auc: 0.9774 - 29s/epoch - 729ms/step
# Epoch 76/100
# 40/40 - 29s - loss: 0.3653 - accuracy: 0.9381 - precision_1: 0.9404 - recall_1: 0.9359 - auc: 0.9921 - val_loss: 0.4957 - val_accuracy: 0.8945 - val_precision_1: 0.8964 - val_recall_1: 0.8919 - val_auc: 0.9777 - 29s/epoch - 724ms/step
# Epoch 77/100
# 40/40 - 31s - loss: 0.3579 - accuracy: 0.9392 - precision_1: 0.9414 - recall_1: 0.9374 - auc: 0.9927 - val_loss: 0.4899 - val_accuracy: 0.8936 - val_precision_1: 0.8970 - val_recall_1: 0.8904 - val_auc: 0.9777 - 31s/epoch - 768ms/step
# Epoch 78/100
# 40/40 - 29s - loss: 0.3550 - accuracy: 0.9393 - precision_1: 0.9414 - recall_1: 0.9370 - auc: 0.9926 - val_loss: 0.4877 - val_accuracy: 0.8924 - val_precision_1: 0.8949 - val_recall_1: 0.8902 - val_auc: 0.9778 - 29s/epoch - 718ms/step
# Epoch 79/100
# 40/40 - 28s - loss: 0.3518 - accuracy: 0.9406 - precision_1: 0.9427 - recall_1: 0.9388 - auc: 0.9927 - val_loss: 0.4777 - val_accuracy: 0.8937 - val_precision_1: 0.8971 - val_recall_1: 0.8911 - val_auc: 0.9789 - 28s/epoch - 705ms/step
# Epoch 80/100
# 40/40 - 29s - loss: 0.3459 - accuracy: 0.9416 - precision_1: 0.9437 - recall_1: 0.9395 - auc: 0.9931 - val_loss: 0.4829 - val_accuracy: 0.8959 - val_precision_1: 0.8988 - val_recall_1: 0.8942 - val_auc: 0.9785 - 29s/epoch - 714ms/step
# Epoch 81/100
# 40/40 - 29s - loss: 0.3428 - accuracy: 0.9424 - precision_1: 0.9444 - recall_1: 0.9405 - auc: 0.9931 - val_loss: 0.4739 - val_accuracy: 0.8953 - val_precision_1: 0.8985 - val_recall_1: 0.8928 - val_auc: 0.9790 - 29s/epoch - 735ms/step
# Epoch 82/100
# 40/40 - 29s - loss: 0.3413 - accuracy: 0.9425 - precision_1: 0.9441 - recall_1: 0.9406 - auc: 0.9931 - val_loss: 0.4779 - val_accuracy: 0.8963 - val_precision_1: 0.8983 - val_recall_1: 0.8943 - val_auc: 0.9782 - 29s/epoch - 713ms/step
# Epoch 83/100
# 40/40 - 30s - loss: 0.3327 - accuracy: 0.9452 - precision_1: 0.9472 - recall_1: 0.9439 - auc: 0.9937 - val_loss: 0.4670 - val_accuracy: 0.9008 - val_precision_1: 0.9048 - val_recall_1: 0.8974 - val_auc: 0.9790 - 30s/epoch - 740ms/step
# Epoch 84/100
# 40/40 - 31s - loss: 0.3299 - accuracy: 0.9447 - precision_1: 0.9467 - recall_1: 0.9428 - auc: 0.9937 - val_loss: 0.4666 - val_accuracy: 0.8996 - val_precision_1: 0.9012 - val_recall_1: 0.8965 - val_auc: 0.9795 - 31s/epoch - 769ms/step
# Epoch 85/100
# 40/40 - 29s - loss: 0.3258 - accuracy: 0.9459 - precision_1: 0.9480 - recall_1: 0.9444 - auc: 0.9939 - val_loss: 0.4671 - val_accuracy: 0.8988 - val_precision_1: 0.9008 - val_recall_1: 0.8972 - val_auc: 0.9793 - 29s/epoch - 736ms/step
# Epoch 86/100
# 40/40 - 30s - loss: 0.3243 - accuracy: 0.9461 - precision_1: 0.9478 - recall_1: 0.9445 - auc: 0.9939 - val_loss: 0.4575 - val_accuracy: 0.9022 - val_precision_1: 0.9041 - val_recall_1: 0.9001 - val_auc: 0.9801 - 30s/epoch - 748ms/step
# Epoch 87/100
# 40/40 - 29s - loss: 0.3213 - accuracy: 0.9476 - precision_1: 0.9495 - recall_1: 0.9463 - auc: 0.9940 - val_loss: 0.4539 - val_accuracy: 0.8993 - val_precision_1: 0.9036 - val_recall_1: 0.8963 - val_auc: 0.9795 - 29s/epoch - 716ms/step
# Epoch 88/100
# 40/40 - 29s - loss: 0.3160 - accuracy: 0.9476 - precision_1: 0.9497 - recall_1: 0.9462 - auc: 0.9943 - val_loss: 0.4690 - val_accuracy: 0.8971 - val_precision_1: 0.8990 - val_recall_1: 0.8959 - val_auc: 0.9784 - 29s/epoch - 716ms/step
# Epoch 89/100
# 40/40 - 30s - loss: 0.3098 - accuracy: 0.9506 - precision_1: 0.9525 - recall_1: 0.9492 - auc: 0.9947 - val_loss: 0.4505 - val_accuracy: 0.9036 - val_precision_1: 0.9058 - val_recall_1: 0.9017 - val_auc: 0.9803 - 30s/epoch - 746ms/step
# Epoch 90/100
# 40/40 - 29s - loss: 0.3098 - accuracy: 0.9496 - precision_1: 0.9509 - recall_1: 0.9477 - auc: 0.9945 - val_loss: 0.4468 - val_accuracy: 0.9022 - val_precision_1: 0.9046 - val_recall_1: 0.8997 - val_auc: 0.9806 - 29s/epoch - 722ms/step
# Epoch 91/100
# 40/40 - 29s - loss: 0.3040 - accuracy: 0.9505 - precision_1: 0.9521 - recall_1: 0.9494 - auc: 0.9948 - val_loss: 0.4406 - val_accuracy: 0.9050 - val_precision_1: 0.9074 - val_recall_1: 0.9029 - val_auc: 0.9809 - 29s/epoch - 734ms/step
# Epoch 92/100
# 40/40 - 29s - loss: 0.3053 - accuracy: 0.9494 - precision_1: 0.9512 - recall_1: 0.9482 - auc: 0.9945 - val_loss: 0.4480 - val_accuracy: 0.9030 - val_precision_1: 0.9053 - val_recall_1: 0.8996 - val_auc: 0.9801 - 29s/epoch - 732ms/step
# Epoch 93/100
# 40/40 - 32s - loss: 0.2957 - accuracy: 0.9528 - precision_1: 0.9542 - recall_1: 0.9513 - auc: 0.9951 - val_loss: 0.4448 - val_accuracy: 0.9043 - val_precision_1: 0.9067 - val_recall_1: 0.9031 - val_auc: 0.9802 - 32s/epoch - 803ms/step
# Epoch 94/100
# 40/40 - 29s - loss: 0.2967 - accuracy: 0.9528 - precision_1: 0.9542 - recall_1: 0.9515 - auc: 0.9949 - val_loss: 0.4405 - val_accuracy: 0.9083 - val_precision_1: 0.9106 - val_recall_1: 0.9064 - val_auc: 0.9810 - 29s/epoch - 736ms/step
# Epoch 95/100
# 40/40 - 29s - loss: 0.2880 - accuracy: 0.9552 - precision_1: 0.9566 - recall_1: 0.9539 - auc: 0.9955 - val_loss: 0.4376 - val_accuracy: 0.9058 - val_precision_1: 0.9081 - val_recall_1: 0.9044 - val_auc: 0.9804 - 29s/epoch - 732ms/step
# Epoch 96/100
# 40/40 - 31s - loss: 0.2883 - accuracy: 0.9537 - precision_1: 0.9552 - recall_1: 0.9527 - auc: 0.9954 - val_loss: 0.4330 - val_accuracy: 0.9060 - val_precision_1: 0.9083 - val_recall_1: 0.9048 - val_auc: 0.9810 - 31s/epoch - 774ms/step
# Epoch 97/100
# 40/40 - 29s - loss: 0.2831 - accuracy: 0.9558 - precision_1: 0.9572 - recall_1: 0.9548 - auc: 0.9957 - val_loss: 0.4368 - val_accuracy: 0.9040 - val_precision_1: 0.9070 - val_recall_1: 0.9029 - val_auc: 0.9807 - 29s/epoch - 720ms/step
# Epoch 98/100
# 40/40 - 29s - loss: 0.2822 - accuracy: 0.9553 - precision_1: 0.9570 - recall_1: 0.9542 - auc: 0.9956 - val_loss: 0.4317 - val_accuracy: 0.9048 - val_precision_1: 0.9068 - val_recall_1: 0.9038 - val_auc: 0.9812 - 29s/epoch - 720ms/step
# Epoch 99/100
# 40/40 - 29s - loss: 0.2857 - accuracy: 0.9535 - precision_1: 0.9549 - recall_1: 0.9518 - auc: 0.9952 - val_loss: 0.4262 - val_accuracy: 0.9073 - val_precision_1: 0.9100 - val_recall_1: 0.9055 - val_auc: 0.9814 - 29s/epoch - 717ms/step
# Epoch 100/100
# 40/40 - 29s - loss: 0.2775 - accuracy: 0.9566 - precision_1: 0.9583 - recall_1: 0.9551 - auc: 0.9956 - val_loss: 0.4271 - val_accuracy: 0.9072 - val_precision_1: 0.9099 - val_recall_1: 0.9054 - val_auc: 0.9817 - 29s/epoch - 734ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to: /content/drive/My Drive/ML_Data/saved_model/triangle/mobilenetv3_model_20241017_035631.h5

# %%
# Cell 9: Plot training history
def plot_training_history(history):
    plt.figure(figsize=(16, 8))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss')

    # Save the figure as a PNG in the /content directory
    plt.tight_layout()
    plt.savefig('/content/training_history.png', format='png')  # Explicitly save as PNG
    print('Training history plot saved to: /content/training_history.png')


plot_training_history(history)
# Out:
# Training history plot saved to: /content/training_history.png

# %%
# Cell 10: Generate predictions and classification report, ROC curve, and other metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, f1_score, accuracy_score, precision_score, recall_score
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os

# Define function to evaluate the model
def evaluate_model_on_test_data(model, test_dataset, class_names):
    # Generate predictions on the test dataset
    y_pred = np.argmax(model.predict(test_dataset), axis=1)

    # Extract true labels from the dataset
    y_true = []
    for images, labels in test_dataset:
        y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_true = np.array(y_true)

    # Confusion Matrix
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted'); plt.ylabel('True')
    plt.title('Confusion Matrix - Test Set')

    # Save confusion matrix plot
    plot_save_dir = "plots/"
    if not os.path.exists(plot_save_dir):
        os.makedirs(plot_save_dir)
    confusion_matrix_plot_path = os.path.join(plot_save_dir, 'confusion_matrix.png')
    plt.savefig(confusion_matrix_plot_path)
    print(f"Confusion matrix plot saved to: {confusion_matrix_plot_path}")
    plt.show()

    # Classification Report
    report = classification_report(y_true, y_pred, target_names=class_names)
    print(f"Classification Report:\n{report}")

    # F1, Precision, Recall, Accuracy
    f1 = f1_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    accuracy = accuracy_score(y_true, y_pred)

    print(f"Test Accuracy: {accuracy:.4f}")
    print(f"Test F1 Score (Weighted): {f1:.4f}")
    print(f"Test Precision (Weighted): {precision:.4f}")
    print(f"Test Recall (Weighted): {recall:.4f}")

    # ROC Curve and AUC Score for each class
    y_prob = model.predict(test_dataset)
    plt.figure(figsize=(10, 8))

    for i, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true == i, y_prob[:, i])
        plt.plot(fpr, tpr, label=f'Class {class_name} (AUC = {roc_auc_score(y_true == i, y_prob[:, i]):.2f})')

    plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Test Set')
    plt.legend()

    # Save ROC plot
    roc_plot_path = os.path.join(plot_save_dir, 'roc_curve.png')
    plt.savefig(roc_plot_path)
    print(f"ROC curve plot saved to: {roc_plot_path}")
    plt.show()

# Call the evaluation function
evaluate_model_on_test_data(model, test_dataset, class_names)
# Out:
# 9/9 [==============================] - 19s 1s/step
# Confusion matrix plot saved to: plots/confusion_matrix.png
# Classification Report:
#               precision    recall  f1-score   support
#
#           hc       0.92      0.91      0.92      2781
#           pd       0.89      0.92      0.90      2858
#    prodromal       0.91      0.90      0.90      2993
#
#     accuracy                           0.91      8632
#    macro avg       0.91      0.91      0.91      8632
# weighted avg       0.91      0.91      0.91      8632
#
# Test Accuracy: 0.9070
# Test F1 Score (Weighted): 0.9070
# Test Precision (Weighted): 0.9073
# Test Recall (Weighted): 0.9070
# 9/9 [==============================] - 6s 452ms/step
# ROC curve plot saved to: plots/roc_curve.png
